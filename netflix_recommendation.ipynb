# %%
import pandas as pd

# %%
movies = pd.read_csv('data.csv')

# %%
movies.head(10)
# Out:
#        id                        title                     genre  \
# 0     278     The Shawshank Redemption               Drama,Crime
# 1   19404  Dilwale Dulhania Le Jayenge      Comedy,Drama,Romance
# 2     238                The Godfather               Drama,Crime
# 3     424             Schindler's List         Drama,History,War
# 4     240       The Godfather: Part II               Drama,Crime
# 5  667257            Impossible Things              Family,Drama
# 6     129                Spirited Away  Animation,Family,Fantasy
# 7  730154               Your Eyes Tell             Romance,Drama
# 8  372754     Dou kyu sei – Classmates         Romance,Animation
# 9  372058                   Your Name.   Romance,Animation,Drama
#
#   original_language                                           overview  \
# 0                en  Framed in the 1940s for the double murder of h...
# 1                hi  Raj is a rich, carefree, happy-go-lucky second...
# ...

# %%
movies.describe()
# Out:
#                   id    popularity  vote_average    vote_count
# count   10000.000000  10000.000000  10000.000000  10000.000000
# mean   161243.505000     34.697267      6.621150   1547.309400
# std    211422.046043    211.684175      0.766231   2648.295789
# min         5.000000      0.600000      4.600000    200.000000
# 25%     10127.750000      9.154750      6.100000    315.000000
# 50%     30002.500000     13.637500      6.600000    583.500000
# 75%    310133.500000     25.651250      7.200000   1460.000000
# max    934761.000000  10436.917000      8.700000  31917.000000

# %%
movies.isnull().sum()
# Out:
# id                    0
# title                 0
# genre                 3
# original_language     0
# overview             13
# popularity            0
# release_date          0
# vote_average          0
# vote_count            0
# dtype: int64

# %%
movies.columns
# Out:
# Index(['id', 'title', 'genre', 'original_language', 'overview', 'popularity',
#        'release_date', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies=movies[['id', 'title', 'overview', 'genre']]

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
movies['tags'] = movies['overview']+movies['genre']

# %%
movies
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                overview  \
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
new_data  = movies.drop(columns=['overview', 'genre'])

# %%
new_data
# Out:
#           id                                          title  \
# 0        278                       The Shawshank Redemption
# 1      19404                    Dilwale Dulhania Le Jayenge
# 2        238                                  The Godfather
# 3        424                               Schindler's List
# 4        240                         The Godfather: Part II
# ...      ...                                            ...
# 9995   10196                             The Last Airbender
# 9996  331446                       Sharknado 3: Oh Hell No!
# 9997   13995                                Captain America
# 9998    2312  In the Name of the King: A Dungeon Siege Tale
# 9999  455957                                         Domino
#
#                                                    tags
# 0     Framed in the 1940s for the double murder of h...
# 1     Raj is a rich, carefree, happy-go-lucky second...
# 2     Spanning the years 1945 to 1955, a chronicle o...
# ...

# %%
'''
max_features: This parameter specifies the maximum number of features (unique words or tokens) to be extracted. In your case, it's set to 10,000, meaning that only the top 10,000 most frequently occurring words in the corpus will be considered as features.

stop_words: This parameter is used to specify a list of words that should be ignored during the tokenization process. In this case, 'english' indicates that a built-in list of English stop words provided by scikit-learn will be used. Stop words are common words such as 'the', 'is', 'and', etc., which are often removed because they typically do not carry significant meaning for text analysis.

When you use CountVectorizer with these parameters, it creates a matrix representation of the text data, where rows correspond to documents and columns correspond to features (words or tokens). Each cell in the matrix contains the count of how many times a particular word appears in the corresponding document. This matrix can then be used as input to machine learning algorithms for tasks such as classification, clustering, or regression.


User
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()
ChatGPT
The code you provided is using the fit_transform() method of the CountVectorizer object (cv) to transform the text data in the 'tags' column of the DataFrame new_data into a matrix of token counts, and then converting it to a NumPy array using toarray() method.

Here's a breakdown of what each part of the code does:

new_data['tags'].values.astype('U'): This extracts the values from the 'tags' column of the DataFrame new_data and converts them to a NumPy array with Unicode data type ('U'). This step is necessary because fit_transform() expects an iterable of string values.

cv.fit_transform(...): This method fits the CountVectorizer object cv to the text data and transforms it into a matrix of token counts. It both learns the vocabulary (i.e., the unique words or tokens) from the text data and transforms the text data into a matrix representation.

.toarray(): This converts the matrix representation returned by fit_transform() into a NumPy array. The matrix representation returned by fit_transform() is typically in a sparse format (i.e., only non-zero elements are stored explicitly), but toarray() converts it into a dense NumPy array format where all elements are stored explicitly.

So, after executing this code, the variable vector will contain a NumPy array representing the matrix of token counts derived from the text data in the 'tags' column of the new_data DataFrame. Each row of the array corresponds to a document (i.e., a tag in this case), and each column corresponds to a unique word or token in the vocabulary learned by the CountVectorizer. The value at position (i, j) in the array represents the count of the j-th word in the i-th document.

User
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vector)
similarity
explain 
ChatGPT
The code snippet you provided is using the cosine_similarity function from scikit-learn's metrics.pairwise module to compute the cosine similarity between the rows (vectors) of the vector array, which likely contains the document-term matrix created using CountVectorizer.

Here's a breakdown of what the code does:

from sklearn.metrics.pairwise import cosine_similarity: This imports the cosine_similarity function from scikit-learn's metrics.pairwise module. Cosine similarity is a metric used to measure the similarity between two vectors in a vector space. It calculates the cosine of the angle between two vectors, which is a measure of how similar or related they are.

similarity = cosine_similarity(vector): This line computes the cosine similarity between all pairs of vectors (rows) in the vector array. Since vector likely represents a document-term matrix where each row corresponds to a document (tag) and each column corresponds to a term (word), cosine_similarity(vector) will compute the cosine similarity between all pairs of documents based on their term frequencies.

similarity: This variable will contain a symmetric matrix where each element (i, j) represents the cosine similarity between the i-th and j-th documents. The diagonal elements (i.e., where i == j) will be 1 because the cosine similarity between a document and itself is 1.

The resulting similarity matrix can be used to identify documents that are similar to each other based on their term frequencies. Higher cosine similarity values indicate greater similarity between documents, while lower values indicate less similarity. This similarity matrix can be useful for various tasks such as clustering similar documents together, identifying related documents, or building recommendation systems.

User
from sklearn.metrics.pairwise import cosine_similarity
similarity=cosine_similarity(vector)
similarity 
explain the code 
ChatGPT
Certainly! This code snippet calculates the cosine similarity between vectors using scikit-learn's cosine_similarity function. Here's a detailed explanation:

Importing the necessary module and function:

python
Copy code
from sklearn.metrics.pairwise import cosine_similarity
This line imports the cosine_similarity function from scikit-learn's metrics.pairwise module. This function is specifically designed to compute the cosine similarity between vectors.

Computing cosine similarity:

python
Copy code
similarity = cosine_similarity(vector)
This line calculates the cosine similarity between all pairs of vectors in the vector array. The vector array likely represents a document-term matrix, where each row corresponds to a document (tag) and each column corresponds to a term (word). By default, cosine_similarity calculates the cosine similarity between all pairs of row vectors in the input array. In this case, it calculates the cosine similarity between all pairs of documents based on their term frequencies.

Output:

python
Copy code
similarity
This simply prints or returns the similarity matrix, which contains the cosine similarity values between all pairs of documents. The resulting matrix is symmetric, with each element (i, j) representing the cosine similarity between the i-th and j-th documents.

The cosine similarity is a measure of similarity between two non-zero vectors in an inner product space. It measures the cosine of the angle between the vectors and ranges from -1 to 1, where 1 indicates that the vectors are identical in direction, 0 indicates orthogonality (no similarity), and -1 indicates complete dissimilarity (opposite direction). In the context of document analysis, cosine similarity is commonly used to measure the similarity between documents based on their term frequencies. Higher cosine similarity values imply greater similarity between documents./*

'''
# Out:
# "\nmax_features: This parameter specifies the maximum number of features (unique words or tokens) to be extracted. In your case, it's set to 10,000, meaning that only the top 10,000 most frequently occurring words in the corpus will be considered as features.\n\nstop_words: This parameter is used to specify a list of words that should be ignored during the tokenization process. In this case, 'english' indicates that a built-in list of English stop words provided by scikit-learn will be used. Stop words are common words such as 'the', 'is', 'and', etc., which are often removed because they typically do not carry significant meaning for text analysis.\n\nWhen you use CountVectorizer with these parameters, it creates a matrix representation of the text data, where rows correspond to documents and columns correspond to features (words or tokens). Each cell in the matrix contains the count of how many times a particular word appears in the corresponding document. This matrix can then be u
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv=CountVectorizer(max_features=10000, stop_words='english')

# %%
cv
# Out:
# CountVectorizer(max_features=10000, stop_words='english')

# %%
vector=cv.fit_transform(new_data['tags'].values.astype('U')).toarray()

# %%
vector.shape
# Out:
# (10000, 10000)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.05634362, 0.12888482, ..., 0.07559289, 0.11065667,
#         0.06388766],
#        [0.05634362, 1.        , 0.07624929, ..., 0.        , 0.03636965,
#         0.        ],
#        [0.12888482, 0.07624929, 1.        , ..., 0.02273314, 0.06655583,
#         0.08645856],
#        ...,
#        [0.07559289, 0.        , 0.02273314, ..., 1.        , 0.03253   ,
#         0.02817181],
#        [0.11065667, 0.03636965, 0.06655583, ..., 0.03253   , 1.        ,
#         0.0412393 ],
#        [0.06388766, 0.        , 0.08645856, ..., 0.02817181, 0.0412393 ,
#         1.        ]])

# %%
new_data[new_data['title']=="The Godfather"].index[0]
# Out:
# 2

# %%
distance = sorted(list(enumerate(similarity[2])), reverse=True, key=lambda vector:vector[1])
for i in distance[0:8]:
    print(new_data.iloc[i[0]].title)
# Out:
# The Godfather
# The Godfather: Part II
# Blood Ties
# Joker
# Bomb City
# Gotti
# Felon
# Rope

# %%
def recommand(movies):
    index=new_data[new_data['title']==movies].index[0]
    distance = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda vector:vector[1])
    for i in distance[0:5]:
        print(new_data.iloc[i[0]].title)

# %%
recommand("Set It Up")
# Out:
# Set It Up
# Tel chi el telùn
# Mystic Pizza
# Sex, Love & Therapy
# Sierra Burgess Is a Loser
